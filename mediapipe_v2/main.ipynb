# %%
import cv2
import mediapipe as mp
import math

# 初始化 MediaPipe Pose 模型
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# 计算两点之间的倾斜角度
def calculate_inclination(left_hip, right_hip):
    # 使用 atan2 计算倾斜角度
    dy = right_hip[1] - left_hip[1]  # y 的差值
    dx = right_hip[0] - left_hip[0]  # x 的差值
    angle_radians = math.atan2(dy, dx)  # 计算弧度
    angle_degrees = math.degrees(angle_radians)  # 转换为度数
    return angle_degrees

def rescale_frame(frame, percent=75):
    width = int(frame.shape[1] * percent/ 100)
    height = int(frame.shape[0] * percent/ 100)
    dim = (width, height)
    return cv2.resize(frame, dim, interpolation =cv2.INTER_AREA)

# 打开视频文件
cap = cv2.VideoCapture("IMG_7239.MOV")
#cap = cv2.VideoCapture("1.png")



# 使用 MediaPipe Pose 进行骨架检测
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # 将图像从 BGR 转换为 RGB
        img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(img_rgb)
        

        # 如果检测到骨架
        if results.pose_landmarks:
            # 获取左右髋部的坐标
            landmarks = results.pose_landmarks.landmark
            
            left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, 
                        landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
            right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x, 
                         landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]

            # 计算水平方向的倾斜角度
            inclination_angle = calculate_inclination(left_hip, right_hip)
            print(f"Inclination Angle between hips: {inclination_angle} degrees")

            # 绘制骨架
            mp_drawing.draw_landmarks(
                frame, 
                results.pose_landmarks, 
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2)
            )


        
        # 显示处理后的图像
        
        #rescaled_frame=rescale_frame(frame,percent=compress)
        cv2.imshow('Pose Estimation', frame)

        

        if cv2.waitKey(5) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Inclination Angle between hips: -16.707482327299182 degrees
# Inclination Angle between hips: -13.57861705229155 degrees
# Inclination Angle between hips: -23.695954294709793 degrees
# Inclination Angle between hips: -20.845580079289544 degrees
# Inclination Angle between hips: -15.864310356864483 degrees
# Inclination Angle between hips: 2.4754554185589486 degrees
# Inclination Angle between hips: 9.286858434172785 degrees
# Inclination Angle between hips: 14.326196029199377 degrees
# Inclination Angle between hips: 13.793788411579628 degrees
# Inclination Angle between hips: 9.273172519090027 degrees
# Inclination Angle between hips: 7.689547025824763 degrees
# Inclination Angle between hips: 10.125230174809067 degrees
# Inclination Angle between hips: 12.453386863136046 degrees
# Inclination Angle between hips: 12.562287153514353 degrees
# Inclination Angle between hips: 14.049171900243172 degrees
# Inclination Angle between hips: 13.171345151563358 degrees
# Inclination Angle between hips: 12.518128521189096 degrees
# Inclination Angle between hips: 11.291977724566832 degrees
# Inclination Angle between hips: 11.052071826737878 degrees
# Inclination Angle between hips: 9.453800606385803 degrees
# Inclination Angle between hips: 8.956688136430682 degrees
# Inclination Angle between hips: 7.957842817901834 degrees
# Inclination Angle between hips: 8.358633735278673 degrees
# Inclination Angle between hips: 9.416649520667013 degrees
# Inclination Angle between hips: 9.833896513797933 degrees
# Inclination Angle between hips: 9.732261036752924 degrees
# Inclination Angle between hips: 7.7686122602300784 degrees
# Inclination Angle between hips: 7.933547589819106 degrees
# Inclination Angle between hips: 6.308850410896759 degrees
# Inclination Angle between hips: 6.512286088238453 degrees
# Inclination Angle between hips: 7.390193016835706 degrees
# Inclination Angle between hips: 8.01156212217863 degrees
# Inclination Angle between hips: 8.914901730636787 degrees
# Inclination Angle between hips: 7.952191944758995 degrees
# Inclination Angle between hips: 8.080466152292145 degrees
# Inclination Angle between hips: 8.807139845722773 degrees
# Inclination Angle between hips: 6.827543650147505 degrees
# Inclination Angle between hips: 4.101742947969496 degrees
# Inclination Angle between hips: 1.772453935167644 degrees
# Inclination Angle between hips: 0.6144538401241778 degrees
# Inclination Angle between hips: -1.0247837937163757 degrees
# Inclination Angle between hips: -2.5202710332612535 degrees
# Inclination Angle between hips: -2.420538140731762 degrees
# Inclination Angle between hips: -2.493019139927312 degrees
# Inclination Angle between hips: -2.9891675830650555 degrees
# Inclination Angle between hips: -2.3433921530934136 degrees
# Inclination Angle between hips: -4.454584179846002 degrees
# Inclination Angle between hips: -5.032062820578961 degrees
# Inclination Angle between hips: -1.7391924597123594 degrees
# Inclination Angle between hips: -3.3819941520864587 degrees
# Inclination Angle between hips: -4.114405887578727 degrees
# Inclination Angle between hips: -3.0066843924341717 degrees
# Inclination Angle between hips: -0.39558969903562996 degrees
# Inclination Angle between hips: 4.181267217625385 degrees
# Inclination Angle between hips: 7.656125887024855 degrees
# Inclination Angle between hips: 11.787743136518523 degrees
# Inclination Angle between hips: 9.215213733955798 degrees
# Inclination Angle between hips: 6.838973953428284 degrees
# Inclination Angle between hips: 5.602747621038114 degrees
# Inclination Angle between hips: 3.529828591250015 degrees
# Inclination Angle between hips: 2.3065184334850857 degrees
# Inclination Angle between hips: 1.848612378321168 degrees
# Inclination Angle between hips: 1.1456165393034166 degrees
# Inclination Angle between hips: 1.201976230367674 degrees
# Inclination Angle between hips: 1.1129368527501655 degrees
# Inclination Angle between hips: 0.5113361561333217 degrees
# Inclination Angle between hips: 0.5818221589602824 degrees
# Inclination Angle between hips: 1.2807627747637065 degrees
# Inclination Angle between hips: 1.7747741122950424 degrees
# Inclination Angle between hips: 2.384404502393265 degrees
# Inclination Angle between hips: 0.7913479035088399 degrees
# Inclination Angle between hips: -1.862232236381694 degrees
# Inclination Angle between hips: -2.4692265989168973 degrees
# Inclination Angle between hips: -3.1523532685202666 degrees
# Inclination Angle between hips: -4.926929330354145 degrees
# Inclination Angle between hips: -4.981369623781082 degrees
# Inclination Angle between hips: -5.417950142139425 degrees
# Inclination Angle between hips: -5.53550159732387 degrees
# Inclination Angle between hips: -5.302012138045216 degrees
# Inclination Angle between hips: -5.193732504509042 degrees
# Inclination Angle between hips: -3.9287350307820748 degrees
# Inclination Angle between hips: -1.0760079444571975 degrees
# Inclination Angle between hips: 3.0809559218734495 degrees
# Inclination Angle between hips: 5.778592708388292 degrees
# Inclination Angle between hips: 5.466390502960134 degrees
# Inclination Angle between hips: 6.029900634559762 degrees
# Inclination Angle between hips: 5.945275000071321 degrees
# Inclination Angle between hips: 5.423683992124718 degrees
# Inclination Angle between hips: 5.3888085055272 degrees
# Inclination Angle between hips: 6.881040874551839 degrees
# Inclination Angle between hips: 7.444293242630115 degrees
# Inclination Angle between hips: 8.115676115074695 degrees
# Inclination Angle between hips: 8.773444367220714 degrees
# Inclination Angle between hips: 9.196693762686966 degrees
# Inclination Angle between hips: 8.752116367876894 degrees
# Inclination Angle between hips: 7.495741749196541 degrees
# Inclination Angle between hips: 7.91294237682409 degrees
# Inclination Angle between hips: 7.951728743547901 degrees
# Inclination Angle between hips: 9.279704122228527 degrees
# Inclination Angle between hips: 10.111205274894619 degrees
# Inclination Angle between hips: 11.794017026706161 degrees
# Inclination Angle between hips: 14.378223749663801 degrees
# Inclination Angle between hips: 19.581444385194697 degrees
# Inclination Angle between hips: 24.742692585897796 degrees
# Inclination Angle between hips: 32.69584592201807 degrees
# Inclination Angle between hips: 42.88833596005173 degrees
# Inclination Angle between hips: 40.41918182854545 degrees
# Inclination Angle between hips: 33.90567796651855 degrees
# Inclination Angle between hips: 36.244198353472804 degrees
# Inclination Angle between hips: 24.64818516642831 degrees
# Inclination Angle between hips: 17.29398504071638 degrees
# Inclination Angle between hips: 13.547832350443535 degrees
# Inclination Angle between hips: 13.933879832376729 degrees
# Inclination Angle between hips: 12.230957289593077 degrees
# Inclination Angle between hips: 16.224031798626303 degrees
# Inclination Angle between hips: 15.255567559095368 degrees
# Inclination Angle between hips: 17.524054087001087 degrees
# Inclination Angle between hips: 19.71966036507532 degrees
# Inclination Angle between hips: 21.52960456789881 degrees
# Inclination Angle between hips: 22.396219359595047 degrees
# Inclination Angle between hips: 24.147707691223985 degrees
# Inclination Angle between hips: 27.1623045601885 degrees
# Inclination Angle between hips: 26.73742353840681 degrees
# Inclination Angle between hips: 27.746930568143362 degrees
# Inclination Angle between hips: 28.343395122463793 degrees
# Inclination Angle between hips: 29.581168756501615 degrees
# Inclination Angle between hips: 31.08619403355393 degrees
# Inclination Angle between hips: 32.69411448947465 degrees
# Inclination Angle between hips: 32.319909325628146 degrees
# Inclination Angle between hips: 32.55055643984961 degrees
# Inclination Angle between hips: 31.946376246954078 degrees
# Inclination Angle between hips: 30.84070161364056 degrees
# Inclination Angle between hips: 31.094473793640592 degrees
# Inclination Angle between hips: 31.05816080384998 degrees
# Inclination Angle between hips: 31.48782155108325 degrees
# Inclination Angle between hips: 30.342957931889007 degrees
# Inclination Angle between hips: 24.871819157312753 degrees
# Inclination Angle between hips: 22.860822156423023 degrees
# Inclination Angle between hips: 23.45611635333931 degrees
# Inclination Angle between hips: 22.36726047928181 degrees
# Inclination Angle between hips: 20.79423351537008 degrees
# Inclination Angle between hips: 19.469003714974228 degrees
# Inclination Angle between hips: 17.9219164876537 degrees
# Inclination Angle between hips: 15.957949717235268 degrees
# Inclination Angle between hips: 14.052723503895203 degrees
# Inclination Angle between hips: 13.950798401110317 degrees
# Inclination Angle between hips: 10.271653187863127 degrees
# Inclination Angle between hips: 9.525433667154674 degrees
# Inclination Angle between hips: 9.197566883562676 degrees
# Inclination Angle between hips: 9.705691238371259 degrees
# Inclination Angle between hips: 9.807545266562334 degrees
# Inclination Angle between hips: 8.017717999352397 degrees
# Inclination Angle between hips: 7.589983030444938 degrees
# Inclination Angle between hips: 7.221513820663615 degrees
# Inclination Angle between hips: 7.530191012044858 degrees
# Inclination Angle between hips: 6.300375551771061 degrees
# Inclination Angle between hips: 7.424239351227492 degrees
# Inclination Angle between hips: 7.399219397223203 degrees
# Inclination Angle between hips: 9.26035296031155 degrees
# Inclination Angle between hips: 9.67295484965751 degrees
# Inclination Angle between hips: 10.149737467593013 degrees
# Inclination Angle between hips: 11.893635455383045 degrees
# Inclination Angle between hips: 12.335093494888127 degrees
# Inclination Angle between hips: 13.273673311126265 degrees
# Inclination Angle between hips: 16.458203584098626 degrees
# Inclination Angle between hips: 19.60518039664164 degrees
# Inclination Angle between hips: 24.658058112110147 degrees
# Inclination Angle between hips: 26.16615542483967 degrees
# Inclination Angle between hips: 27.359592121451087 degrees
# Inclination Angle between hips: 27.910972748295812 degrees
# Inclination Angle between hips: 27.725689635743294 degrees
# Inclination Angle between hips: 24.652099001357847 degrees
# Inclination Angle between hips: 22.472009115901134 degrees
# Inclination Angle between hips: 21.519493348177924 degrees
# Inclination Angle between hips: 19.1053768589493 degrees
# Inclination Angle between hips: 20.21238205987241 degrees
# Inclination Angle between hips: 16.87912873875318 degrees
# Inclination Angle between hips: 15.091392985552295 degrees
# Inclination Angle between hips: 11.961552426223454 degrees
# Inclination Angle between hips: 11.774446240536879 degrees
# Inclination Angle between hips: 10.123959781729239 degrees
# Inclination Angle between hips: 12.156409823276245 degrees
# Inclination Angle between hips: 15.33702997979829 degrees
# Inclination Angle between hips: 21.634922372394968 degrees
# Inclination Angle between hips: 24.281064721133387 degrees
# Inclination Angle between hips: 20.683979965949828 degrees
# Inclination Angle between hips: 20.055896032165027 degrees
# Inclination Angle between hips: 17.827122574436423 degrees
# Inclination Angle between hips: 18.717393073792763 degrees
# Inclination Angle between hips: 14.562237354925136 degrees
# Inclination Angle between hips: 6.170680582067465 degrees
# Inclination Angle between hips: 3.303002142952135 degrees
# Inclination Angle between hips: -0.5567816128082911 degrees
# Inclination Angle between hips: 6.463706169985165 degrees
# Inclination Angle between hips: 15.775864756083703 degrees
# Inclination Angle between hips: 18.007520651532378 degrees
# Inclination Angle between hips: 15.328622903628384 degrees
# Inclination Angle between hips: 15.463248084151578 degrees
# Inclination Angle between hips: 13.612186898666739 degrees
# Inclination Angle between hips: 12.74942313470179 degrees
# Inclination Angle between hips: 9.610327194099897 degrees
# Inclination Angle between hips: 17.378579548540273 degrees
# Inclination Angle between hips: 34.6453786173577 degrees
# Inclination Angle between hips: 152.81318848900744 degrees
# Inclination Angle between hips: 161.10068463956173 degrees
# Inclination Angle between hips: 162.5149752980812 degrees
# Inclination Angle between hips: 164.74086001227985 degrees
# Inclination Angle between hips: 157.9626261280387 degrees
# Inclination Angle between hips: 161.34461060654786 degrees
# Inclination Angle between hips: 161.91402773504197 degrees
# Inclination Angle between hips: 160.9672484155372 degrees
# Inclination Angle between hips: 158.7958340595821 degrees
# Inclination Angle between hips: 159.30446721536208 degrees
# Inclination Angle between hips: 158.7725704727979 degrees
# Inclination Angle between hips: 158.68503595107853 degrees
# Inclination Angle between hips: 157.36260931912926 degrees
# Inclination Angle between hips: 153.84867428194374 degrees
# Inclination Angle between hips: 147.26967088896967 degrees
# Inclination Angle between hips: 145.30117131279712 degrees
# Inclination Angle between hips: 139.83494529884803 degrees
# Inclination Angle between hips: 136.490433858241 degrees
# Inclination Angle between hips: 134.9130400452678 degrees
# Inclination Angle between hips: 131.6090502503446 degrees
# Inclination Angle between hips: 128.7886362156287 degrees
# Inclination Angle between hips: 126.95729974430593 degrees
# Inclination Angle between hips: 124.41077961531464 degrees
# Inclination Angle between hips: 122.4039752122211 degrees
# Inclination Angle between hips: 121.8546804867422 degrees
# Inclination Angle between hips: 120.14586523960497 degrees
# Inclination Angle between hips: 117.27654430832725 degrees
# Inclination Angle between hips: 116.03817591351509 degrees
# Inclination Angle between hips: 114.44750596321991 degrees
# Inclination Angle between hips: 112.66018013752392 degrees
# Inclination Angle between hips: 113.43260256248053 degrees
# Inclination Angle between hips: 113.75915767306869 degrees
# Inclination Angle between hips: 115.239855759864 degrees
# Inclination Angle between hips: 117.20124987483845 degrees
# Inclination Angle between hips: 117.89870255109479 degrees
# Inclination Angle between hips: 118.31598281485432 degrees
# Inclination Angle between hips: 116.15881676184786 degrees
# Inclination Angle between hips: 114.76085839516078 degrees
# Inclination Angle between hips: 114.86413361046723 degrees
# Inclination Angle between hips: 115.34408227631647 degrees
# Inclination Angle between hips: 117.52096276706483 degrees
# Inclination Angle between hips: 120.3505302363695 degrees
# Inclination Angle between hips: 123.50527261097034 degrees
# Inclination Angle between hips: 127.58321098445732 degrees
# Inclination Angle between hips: 130.88522257382644 degrees
# Inclination Angle between hips: 133.22347935146541 degrees
# Inclination Angle between hips: 136.1325440778723 degrees
# Inclination Angle between hips: 138.06618479985116 degrees
# Inclination Angle between hips: 141.39897315710945 degrees
# Inclination Angle between hips: 145.0943744539399 degrees
# Inclination Angle between hips: 144.72375063262436 degrees
# Inclination Angle between hips: 141.7817636095989 degrees
# Inclination Angle between hips: 139.04703705884202 degrees
# Inclination Angle between hips: 136.84613710994972 degrees
# Inclination Angle between hips: 139.92410471824311 degrees
# Inclination Angle between hips: 142.28547165296376 degrees
# Inclination Angle between hips: 144.5203808177174 degrees
# Inclination Angle between hips: 144.56158375938656 degrees
# Inclination Angle between hips: 143.15695898302172 degrees
# Inclination Angle between hips: 143.0232825656206 degrees
# Inclination Angle between hips: 142.7614778370621 degrees
# Inclination Angle between hips: 144.1600517448555 degrees
# Inclination Angle between hips: 147.60968602711137 degrees
# Inclination Angle between hips: 149.95786874075722 degrees
# Inclination Angle between hips: 151.9891580679181 degrees
# Inclination Angle between hips: 151.8918868624556 degrees
# Inclination Angle between hips: 147.76664577033804 degrees
# Inclination Angle between hips: 145.4821372082885 degrees
# Inclination Angle between hips: 143.58469728111925 degrees
# Inclination Angle between hips: 146.86078810380002 degrees
# Inclination Angle between hips: 145.9680473578778 degrees
# Inclination Angle between hips: 127.09171266843161 degrees
# Inclination Angle between hips: 62.54601138551776 degrees
# Inclination Angle between hips: 44.73950165572288 degrees
# Inclination Angle between hips: 25.323540972099888 degrees
# Inclination Angle between hips: 13.80770494863 degrees
# Inclination Angle between hips: 12.120992998513207 degrees
# Inclination Angle between hips: 7.47300320128127 degrees
# Inclination Angle between hips: 2.566255032412264 degrees
# Inclination Angle between hips: -2.521140540097273 degrees
# Inclination Angle between hips: -8.318225646501956 degrees
# Inclination Angle between hips: -10.636646449300574 degrees
# Inclination Angle between hips: -16.285235838348388 degrees
# Inclination Angle between hips: -12.538886080353324 degrees
# Inclination Angle between hips: -5.988971162838685 degrees
# Inclination Angle between hips: -13.162987330116364 degrees
# Inclination Angle between hips: -8.415376696288762 degrees
# Inclination Angle between hips: -16.825802657922445 degrees
# Inclination Angle between hips: -28.698295057740346 degrees
# Inclination Angle between hips: -26.931189377522966 degrees
# Inclination Angle between hips: -32.84073855206632 degrees
# Inclination Angle between hips: -33.852943380701326 degrees
# Inclination Angle between hips: -29.35529064497185 degrees
# Inclination Angle between hips: -12.606458095479072 degrees
# Inclination Angle between hips: 103.7971918925579 degrees
# Inclination Angle between hips: 110.00086919384418 degrees
# Inclination Angle between hips: 112.46172202312601 degrees
# Inclination Angle between hips: 109.89217882999863 degrees
# Inclination Angle between hips: 11.621816225881439 degrees
# Inclination Angle between hips: 1.086805702369471 degrees
# Inclination Angle between hips: -42.83567236480214 degrees
# Inclination Angle between hips: -46.30285996964845 degrees
# Inclination Angle between hips: -47.96770122506442 degrees
# Inclination Angle between hips: -49.60900308182351 degrees
# Inclination Angle between hips: -50.68456828573501 degrees
# Inclination Angle between hips: -51.29099760962972 degrees
# Inclination Angle between hips: -50.378460542558656 degrees
# Inclination Angle between hips: -50.67297906910735 degrees
# Inclination Angle between hips: -50.51846783906431 degrees
# Inclination Angle between hips: -50.15884696024429 degrees
# Inclination Angle between hips: -50.18727397931778 degrees
# Inclination Angle between hips: -51.61921448225606 degrees
# Inclination Angle between hips: -52.969377230572825 degrees
# Inclination Angle between hips: -53.18393036203622 degrees
# Inclination Angle between hips: -53.74971458246827 degrees
# Inclination Angle between hips: -54.67818872811667 degrees
# Inclination Angle between hips: -55.54806974085457 degrees
# Inclination Angle between hips: -56.26840947111071 degrees
# Inclination Angle between hips: -55.50655734517777 degrees
# Inclination Angle between hips: -57.97233368072046 degrees
# Inclination Angle between hips: -60.69735553098989 degrees
# Inclination Angle between hips: -62.88473678293414 degrees
# Inclination Angle between hips: -64.77535317236205 degrees
# Inclination Angle between hips: -63.658170742849514 degrees
# Inclination Angle between hips: -66.15582533665508 degrees
# Inclination Angle between hips: -67.2946685719419 degrees
# Inclination Angle between hips: -65.15930211400173 degrees
# Inclination Angle between hips: -62.926998590156735 degrees
# Inclination Angle between hips: -60.763358502067675 degrees
# Inclination Angle between hips: -63.59673134620328 degrees
# Inclination Angle between hips: -55.539140275963575 degrees
# Inclination Angle between hips: -51.54132519257643 degrees
# Inclination Angle between hips: -45.74484306993291 degrees
# Inclination Angle between hips: -47.45938457862347 degrees
# Inclination Angle between hips: -42.11271216468857 degrees
# Inclination Angle between hips: -44.428308056932934 degrees
# Inclination Angle between hips: -45.028924786633176 degrees
# Inclination Angle between hips: -42.54398584638767 degrees
# Inclination Angle between hips: -40.02025016127075 degrees
# Inclination Angle between hips: -37.11292444325919 degrees
# Inclination Angle between hips: -36.79195977750624 degrees
# Inclination Angle between hips: -33.293012544076 degrees
# Inclination Angle between hips: -33.23146424826654 degrees
# Inclination Angle between hips: -33.93813592527181 degrees
# Inclination Angle between hips: -30.582771545362874 degrees
# Inclination Angle between hips: -29.853708968582517 degrees
# Inclination Angle between hips: -27.436590422889097 degrees
# Inclination Angle between hips: -25.834519433268184 degrees
# Inclination Angle between hips: -25.813865832595035 degrees
# Inclination Angle between hips: -22.58794616489641 degrees
# Inclination Angle between hips: -18.444729562654924 degrees
# Inclination Angle between hips: -18.435205579659627 degrees
# Inclination Angle between hips: -15.09995313020775 degrees
# Inclination Angle between hips: -15.644156987944518 degrees
# Inclination Angle between hips: -17.848125545395863 degrees
# Inclination Angle between hips: -17.33487484146936 degrees
# Inclination Angle between hips: -15.948071343416562 degrees
# Inclination Angle between hips: -18.075970479031575 degrees
# Inclination Angle between hips: -19.089386898525028 degrees
# Inclination Angle between hips: -20.036062505450165 degrees
# Inclination Angle between hips: -19.764025397504557 degrees
# Inclination Angle between hips: -19.202443950328473 degrees
# Inclination Angle between hips: -19.405456250270195 degrees
# Inclination Angle between hips: -19.069126190502253 degrees
# Inclination Angle between hips: -18.762566650238078 degrees
# Inclination Angle between hips: -17.644687663171013 degrees
# Inclination Angle between hips: -15.455567972944444 degrees
# Inclination Angle between hips: -15.424071361100795 degrees
# Inclination Angle between hips: -14.79784580881055 degrees
# Inclination Angle between hips: -13.886052380088906 degrees
# Inclination Angle between hips: -12.434398645409702 degrees
# Inclination Angle between hips: -11.3864681941415 degrees
# Inclination Angle between hips: -11.376338725602988 degrees
# Inclination Angle between hips: -12.29275277772792 degrees
# Inclination Angle between hips: -12.802418525097533 degrees
# Inclination Angle between hips: -12.948413545052512 degrees
# Inclination Angle between hips: -13.036125028061399 degrees
# Inclination Angle between hips: -11.813361499172501 degrees
# Inclination Angle between hips: -10.603803222404622 degrees
# Inclination Angle between hips: -9.899834564347524 degrees
# Inclination Angle between hips: -9.438368711159459 degrees
# Inclination Angle between hips: -7.991518474584676 degrees
# Inclination Angle between hips: -7.432078869922117 degrees
# Inclination Angle between hips: -6.72014631442035 degrees
# Inclination Angle between hips: -5.85337546526816 degrees
# Inclination Angle between hips: -4.591752615621162 degrees
# Inclination Angle between hips: -4.183417777398288 degrees
# Inclination Angle between hips: -3.9829101850362894 degrees

# %%
import cv2 as cv
import numpy as np

# %%
import cv2
import numpy as np

# 讀取背景影像（無棒球的靜態背景）
background = cv2.imread('1.png')

# 將背景轉換為灰階
gray_background = cv2.cvtColor(background, cv2.COLOR_BGR2GRAY)

# 讀取影片
cap = cv2.VideoCapture('IMG_7239.MOV')

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # 將每幀轉換為灰階
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 調整當前幀大小以匹配背景影像大小
    if gray_background.shape != gray_frame.shape:
        gray_frame = cv2.resize(gray_frame, (gray_background.shape[1], gray_background.shape[0]))

    # 計算背景與當前幀的差異
    diff = cv2.absdiff(gray_background, gray_frame)

    # 應用閾值將差異轉換為二值圖像
    _, foreground_mask = cv2.threshold(diff, 50, 255, cv2.THRESH_BINARY)

    # 去除雜訊
    foreground_mask = cv2.morphologyEx(foreground_mask, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5)))

    # 確保遮罩是 uint8 格式
    foreground_mask = foreground_mask.astype(np.uint8)

    # 檢查遮罩和圖像尺寸是否一致，並調整大小
    if foreground_mask.shape != frame.shape[:2]:
        foreground_mask = cv2.resize(foreground_mask, (frame.shape[1], frame.shape[0]))

    # 使用遮罩保留棒球部分
    foreground = cv2.bitwise_and(frame, frame, mask=foreground_mask)

    # 顯示結果
    cv2.imshow('Foreground', foreground)

    # 按 'q' 鍵退出
    if cv2.waitKey(30) & 0xFF == ord('q'):
        break

# 釋放資源
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# 讀取背景影像（無棒球的靜態背景）
background = cv2.imread('1.png')

# 將背景轉換為灰階
gray_background = cv2.cvtColor(background, cv2.COLOR_BGR2GRAY)

# 讀取影片
cap = cv2.VideoCapture('IMG_7239.MOV')


# 獲取影片的幀寬、高、和每秒幀數（fps）
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# 創建VideoWriter對象來保存結果影片
output = cv2.VideoWriter('output_video.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # 如果沒有讀取到幀，則退出循環

    # 確保當前幀不為空
    if frame is None:
        print("Warning: empty frame encountered.")
        continue

    # 將每幀轉換為灰階
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 調整當前幀大小以匹配背景影像大小
    if gray_background.shape != gray_frame.shape:
        gray_frame = cv2.resize(gray_frame, (gray_background.shape[1], gray_background.shape[0]))

    # 計算背景與當前幀的差異
    diff = cv2.absdiff(gray_background, gray_frame)

    # 應用閾值將差異轉換為二值圖像
    _, foreground_mask = cv2.threshold(diff, 50, 255, cv2.THRESH_BINARY)

    # 去除雜訊
    foreground_mask = cv2.morphologyEx(foreground_mask, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5)))

    # 確保遮罩是 uint8 格式
    foreground_mask = foreground_mask.astype(np.uint8)

    # 檢查遮罩和圖像尺寸是否一致，並調整大小
    if foreground_mask.shape != frame.shape[:2]:
        foreground_mask = cv2.resize(foreground_mask, (frame.shape[1], frame.shape[0]))

    # 使用遮罩保留棒球部分
    foreground = cv2.bitwise_and(frame, frame, mask=foreground_mask)

    # 將結果寫入新影片
    output.write(foreground)

    # 顯示結果（可選）
    cv2.imshow('Foreground', foreground)

    # 按 'q' 鍵退出
    if cv2.waitKey(30) & 0xFF == ord('q'):
        break

# 釋放資源
cap.release()
output.release()  # 釋放影片寫入對象
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# 讀取背景影像（無棒球的靜態背景）
background = cv2.imread('1.png')
if background is None:
    print("Error: Background image not found.")
    exit()

# 將背景轉換為灰階
gray_background = cv2.cvtColor(background, cv2.COLOR_BGR2GRAY)

# 讀取影片
cap = cv2.VideoCapture('IMG_7239.MOV')
if not cap.isOpened():
    print("Error: Video file not found or cannot be opened.")
    exit()

# 獲取影片的幀寬、高、和每秒幀數（fps）
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# 創建VideoWriter對象來保存結果影片
output = cv2.VideoWriter('output_video1.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

def highlight_object(image, mask):
    """高亮顯示被檢測物體"""
    highlighted = image.copy()
    highlighted[mask > 0] = [0, 255, 255]  # 將顏色改為亮黃色
    return highlighted

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # 如果沒有讀取到幀，則退出循環

    # 將每幀轉換為灰階
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 調整當前幀大小以匹配背景影像大小
    if gray_background.shape != gray_frame.shape:
        gray_frame = cv2.resize(gray_frame, (gray_background.shape[1], gray_background.shape[0]))

    # 計算背景與當前幀的差異
    diff = cv2.absdiff(gray_background, gray_frame)

    # 應用閾值將差異轉換為二值圖像
    _, foreground_mask = cv2.threshold(diff, 50, 255, cv2.THRESH_BINARY)

    # 去除雜訊
    foreground_mask = cv2.morphologyEx(foreground_mask, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5)))

    # 檢測輪廓
    contours, _ = cv2.findContours(foreground_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # 檢查是否檢測到任何輪廓
    if contours:
        # 找到最大的輪廓
        largest_contour = max(contours, key=cv2.contourArea)

        # 獲取輪廓的邊界框
        x, y, w, h = cv2.boundingRect(largest_contour)

        # 確保掩碼與當前幀大小一致
        foreground_mask_resized = cv2.resize(foreground_mask, (frame.shape[1], frame.shape[0]))

        # 高亮顯示棒球
        highlighted_frame = highlight_object(frame, foreground_mask_resized)

        # 在原圖上繪製邊界框
        cv2.rectangle(highlighted_frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

        # 將結果寫入新影片
        output.write(highlighted_frame)

        # 顯示結果（可選）
        cv2.imshow('Highlighted Frame', highlighted_frame)

    # 按 'q' 鍵退出
    if cv2.waitKey(30) & 0xFF == ord('q'):
        break

# 釋放資源
cap.release()
output.release()  # 釋放影片寫入對象
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
import math
import time

# 初始化 MediaPipe Pose 模型
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# 计算两点之间的倾斜角度
def calculate_inclination(left_hip, right_hip):
    # 使用 atan2 计算倾斜角度
    dy = right_hip[1] - left_hip[1]  # y 的差值
    dx = right_hip[0] - left_hip[0]  # x 的差值
    angle_radians = math.atan2(dy, dx)  # 计算弧度
    angle_degrees = math.degrees(angle_radians)  # 转换为度数
    return angle_degrees

def rescale_frame(frame, percent=75):
    width = int(frame.shape[1] * percent/ 100)
    height = int(frame.shape[0] * percent/ 100)
    dim = (width, height)
    return cv2.resize(frame, dim, interpolation =cv2.INTER_AREA)

# 打开视频文件
cap = cv2.VideoCapture("IMG_7239.MOV")
#cap = cv2.VideoCapture("1.png")



# 使用 MediaPipe Pose 进行骨架检测
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # 将图像从 BGR 转换为 RGB
        img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(img_rgb)
        

        # 如果检测到骨架
        if results.pose_landmarks:
            # 获取左右髋部的坐标
            landmarks = results.pose_landmarks.landmark
            
            left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, 
                        landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
            right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x, 
                         landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]

            # 计算水平方向的倾斜角度
            inclination_angle = calculate_inclination(left_hip, right_hip)
            time.sleep(0.2)
            print(f"Inclination Angle between hips: {inclination_angle} degrees")

            # 绘制骨架
            mp_drawing.draw_landmarks(
                frame, 
                results.pose_landmarks, 
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2)
            )


        
        # 显示处理后的图像
        
        #rescaled_frame=rescale_frame(frame,percent=compress)
        cv2.imshow('Pose Estimation', frame)

        

        if cv2.waitKey(5) & 0xFF == ord('q'):
            break
        

cap.release()
cv2.destroyAllWindows()
# Out:
# Inclination Angle between hips: -16.707482327299182 degrees
# Inclination Angle between hips: -13.57861705229155 degrees
# Inclination Angle between hips: -23.695954294709793 degrees
# Inclination Angle between hips: -20.845580079289544 degrees
# Inclination Angle between hips: -15.864310356864483 degrees
# Inclination Angle between hips: 2.4754554185589486 degrees
# Inclination Angle between hips: 9.286858434172785 degrees
# Inclination Angle between hips: 14.326196029199377 degrees
# Inclination Angle between hips: 13.793788411579628 degrees
# Inclination Angle between hips: 9.273172519090027 degrees
# Inclination Angle between hips: 7.689547025824763 degrees
# Inclination Angle between hips: 10.125230174809067 degrees
# Inclination Angle between hips: 12.453386863136046 degrees
# Inclination Angle between hips: 12.562287153514353 degrees
# Inclination Angle between hips: 14.049171900243172 degrees
# Inclination Angle between hips: 13.171345151563358 degrees
# Inclination Angle between hips: 12.518128521189096 degrees
# Inclination Angle between hips: 11.291977724566832 degrees
# Inclination Angle between hips: 11.052071826737878 degrees
# Inclination Angle between hips: 9.453800606385803 degrees
# Inclination Angle between hips: 8.956688136430682 degrees
# Inclination Angle between hips: 7.957842817901834 degrees
# Inclination Angle between hips: 8.358633735278673 degrees
# Inclination Angle between hips: 9.416649520667013 degrees
# Inclination Angle between hips: 9.833896513797933 degrees
# Inclination Angle between hips: 9.732261036752924 degrees
# Inclination Angle between hips: 7.7686122602300784 degrees
# Inclination Angle between hips: 7.933547589819106 degrees
# Inclination Angle between hips: 6.308850410896759 degrees

# %%
import cv2
import mediapipe as mp
import math

# 初始化 MediaPipe Pose 模型
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# 计算两个向量之间的夹角
def calculate_angle(a, b, c):
    ba = [a[0] - b[0], a[1] - b[1]]  # 向量 BA
    bc = [c[0] - b[0], c[1] - b[1]]  # 向量 BC
    dot_product = ba[0] * bc[0] + ba[1] * bc[1]
    magnitude_ba = math.sqrt(ba[0]**2 + ba[1]**2)
    magnitude_bc = math.sqrt(bc[0]**2 + bc[1]**2)
    cos_angle = dot_product / (magnitude_ba * magnitude_bc)
    angle = math.degrees(math.acos(cos_angle))
    return angle

# 检查角度是否在预设范围内
def check_angle(name, actual_angle, min_angle, max_angle):
    if actual_angle < min_angle:
        return f"{name} angle too low ({actual_angle:.2f} degrees). Suggested: {min_angle}-{max_angle} degrees."
    elif actual_angle > max_angle:
        return f"{name} angle too high ({actual_angle:.2f} degrees). Suggested: {min_angle}-{max_angle} degrees."
    else:
        return f"{name} angle is correct ({actual_angle:.2f} degrees)."

# 设置各关键关节的标准角度范围
standard_ranges = {
    'left_elbow': (80, 110),   # 投球过程中的肘部角度范围
    'right_elbow': (80, 110), 
    'left_shoulder': (30, 90), # 投球时肩膀角度范围
    'left_hip': (40, 80),      # 髋部的标准角度范围
    'left_knee': (30, 90)      # 膝盖的标准角度范围
}

# 打开视频文件
#cap = cv2.VideoCapture("IMG_7239.MOV")
cap = cv2.VideoCapture("1.mp4")

# 使用 MediaPipe Pose 进行骨架检测
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(img_rgb)

        if results.pose_landmarks:
            landmarks = results.pose_landmarks.landmark

            # 计算各关节角度
            left_elbow_angle = calculate_angle(
                [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y], 
                [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y], 
                [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            )
            right_elbow_angle = calculate_angle(
                [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y], 
                [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y], 
                [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            )
            left_shoulder_angle = calculate_angle(
                [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y], 
                [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y], 
                [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            )
            left_hip_angle = calculate_angle(
                [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y], 
                [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y], 
                [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x, landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
            )
            left_knee_angle = calculate_angle(
                [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y], 
                [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x, landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y], 
                [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
            )

            # 检查角度与标准范围的差距并提供建议
            feedback_left_elbow = check_angle('Left Elbow', left_elbow_angle, *standard_ranges['left_elbow'])
            feedback_right_elbow = check_angle('Right Elbow', right_elbow_angle, *standard_ranges['right_elbow'])
            
            feedback_shoulder = check_angle('Left Shoulder', left_shoulder_angle, *standard_ranges['left_shoulder'])
            feedback_hip = check_angle('Left Hip', left_hip_angle, *standard_ranges['left_hip'])
            feedback_knee = check_angle('Left Knee', left_knee_angle, *standard_ranges['left_knee'])

          
            # 在图像上绘制骨架
            mp_drawing.draw_landmarks(
                frame, 
                results.pose_landmarks, 
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2)
            )

        
        # 显示处理后的图像
        cv2.imshow('Pitcher Pose Analysis', frame)

        if cv2.waitKey(5) & 0xFF == ord('q'):
            break
if check_angle('Right Elbow', right_elbow_angle, *standard_ranges['right_elbow']):
            print(feedback_right_elbow)
            print("手肘角度需調整")
cap.release()
cv2.destroyAllWindows()
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Right Elbow angle too high (175.19 degrees). Suggested: 80-110 degrees.
# 手肘角度需調整

# %%
import cv2
import mediapipe as mp
import math

# 初始化 MediaPipe Pose 模型
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# 计算两个向量之间的夹角
def calculate_angle(a, b, c):
    ba = [a[0] - b[0], a[1] - b[1]]  # 向量 BA
    bc = [c[0] - b[0], c[1] - b[1]]  # 向量 BC
    dot_product = ba[0] * bc[0] + ba[1] * bc[1]
    magnitude_ba = math.sqrt(ba[0]**2 + ba[1]**2)
    magnitude_bc = math.sqrt(bc[0]**2 + bc[1]**2)
    cos_angle = dot_product / (magnitude_ba * magnitude_bc)
    angle = math.degrees(math.acos(cos_angle))
    return angle

# 检查右手肘是否高于肩膀
def is_right_elbow_above_shoulder(landmarks):
    return landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y < landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y

# 检查右手肘角度
def check_right_elbow_angle(angle):
    return 160 <= angle <= 170

# 打开视频文件
cap = cv2.VideoCapture("IMG_7239.MOV")  # 请替换为您的视频文件路径

correct_angle_detected = False

# 使用 MediaPipe Pose 进行骨架检测
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    detection_started = False
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # 将图像从 BGR 转换为 RGB
        img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(img_rgb)

        if results.pose_landmarks:
            landmarks = results.pose_landmarks.landmark

            # 计算右手肘角度
            right_elbow_angle = calculate_angle(
                [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y],
                [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y],
                [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            )

            # 检查是否开始检测
            if not detection_started and is_right_elbow_above_shoulder(landmarks):
                detection_started = True

            # 如果已开始检测，则进行角度检查
            if detection_started:
                if check_right_elbow_angle(right_elbow_angle):
                    correct_angle_detected = True

                # 如果达到结束条件，重置检测状态
                if right_elbow_angle > 170:
                    detection_started = False

            # 绘制骨架
            mp_drawing.draw_landmarks(
                frame, 
                results.pose_landmarks, 
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2)
            )

        # 显示处理后的图像
        cv2.imshow('Pitcher Pose Analysis', frame)

        if cv2.waitKey(5) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# 输出结果
if correct_angle_detected:
    print("在投球过程中，右手肘角度有达到正确范围（160-170度）。")
else:
    print("在整个投球过程中，右手肘角度未达到正确范围（160-170度）。")
# Out:
# 在投球过程中，右手肘角度有达到正确范围（160-170度）。

# %%
import cv2
import mediapipe as mp
import math
import numpy as np

# 初始化 MediaPipe Pose 模型
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# 计算两个向量之间的夹角
def calculate_angle(a, b, c):
    ba = [a[0] - b[0], a[1] - b[1]]  # 向量 BA
    bc = [c[0] - b[0], c[1] - b[1]]  # 向量 BC
    dot_product = ba[0] * bc[0] + ba[1] * bc[1]
    magnitude_ba = math.sqrt(ba[0]**2 + ba[1]**2)
    magnitude_bc = math.sqrt(bc[0]**2 + bc[1]**2)
    cos_angle = dot_product / (magnitude_ba * magnitude_bc)
    angle = math.degrees(math.acos(max(-1, min(1, cos_angle))))
    return angle

# 检查右手肘是否高于肩膀
def is_right_elbow_above_shoulder(landmarks):
    return landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y < landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y

# 检查右手肘角度
def check_right_elbow_angle(angle):
    return 160 <= angle <= 170

# 检查左膝盖角度
def check_left_knee_angle(angle):
    return angle >= 170  # 假设大于170度视为"接近伸直"

# 检查脚尖朝向
def check_foot_direction(landmarks):
    left_foot = np.array([landmarks[mp_pose.PoseLandmark.LEFT_FOOT_INDEX.value].x,
                          landmarks[mp_pose.PoseLandmark.LEFT_FOOT_INDEX.value].y])
    right_foot = np.array([landmarks[mp_pose.PoseLandmark.RIGHT_FOOT_INDEX.value].x,
                           landmarks[mp_pose.PoseLandmark.RIGHT_FOOT_INDEX.value].y])
    foot_direction = left_foot - right_foot
    # 假设y轴正方向为捕手方向，检查脚尖是否大致朝向y轴正方向
    return foot_direction[1] > 0

# 打开视频文件
cap = cv2.VideoCapture("IMG_7239.MOV")  # 请替换为您的视频文件路径

correct_elbow_angle_detected = False
correct_knee_angle_detected = False
correct_foot_direction_detected = False

# 使用 MediaPipe Pose 进行骨架检测
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    detection_started = False
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # 将图像从 BGR 转换为 RGB
        img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(img_rgb)

        if results.pose_landmarks:
            landmarks = results.pose_landmarks.landmark

            # 计算右手肘角度
            right_elbow_angle = calculate_angle(
                [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y],
                [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y],
                [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            )

            # 计算左膝盖角度
            left_knee_angle = calculate_angle(
                [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y],
                [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x, landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y],
                [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
            )

            # 检查是否开始检测
            if not detection_started and is_right_elbow_above_shoulder(landmarks):
                detection_started = True

            # 如果已开始检测，则进行各项检查
            if detection_started:
                if check_right_elbow_angle(right_elbow_angle):
                    correct_elbow_angle_detected = True
                if check_left_knee_angle(left_knee_angle):
                    correct_knee_angle_detected = True
                if check_foot_direction(landmarks):
                    correct_foot_direction_detected = True

                # 如果达到结束条件，重置检测状态
                if right_elbow_angle > 170:
                    detection_started = False

            # 绘制骨架
            mp_drawing.draw_landmarks(
                frame, 
                results.pose_landmarks, 
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2)
            )

        # 显示处理后的图像
        cv2.imshow('Pitcher Pose Analysis', frame)

        if cv2.waitKey(5) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# 输出结果
print("投球姿势分析结果：")
if correct_elbow_angle_detected:
    print("- 右手肘角度有达到正确范围（160-170度）。")
else:
    print("- 右手肘角度未达到正确范围（160-170度）。")

if correct_knee_angle_detected:
    print("- 投球动作结束时，左膝盖接近伸直。")
else:
    print("- 投球动作结束时，左膝盖未充分伸直。")

if correct_foot_direction_detected:
    print("- 脚尖正确朝向捕手方向。")
else:
    print("- 脚尖未正确朝向捕手方向。")
# Out:
# 投球姿势分析结果：
# - 右手肘角度有达到正确范围（160-170度）。
# - 投球动作结束时，左膝盖接近伸直。
# - 脚尖正确朝向捕手方向。

# %%
import cv2
import mediapipe as mp
import math
import numpy as np

# 初始化 MediaPipe Pose 模型
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# 计算两个向量之间的夹角
def calculate_angle(a, b, c):
    ba = [a[0] - b[0], a[1] - b[1]]  # 向量 BA
    bc = [c[0] - b[0], c[1] - b[1]]  # 向量 BC
    dot_product = ba[0] * bc[0] + ba[1] * bc[1]
    magnitude_ba = math.sqrt(ba[0]**2 + ba[1]**2)
    magnitude_bc = math.sqrt(bc[0]**2 + bc[1]**2)
    cos_angle = dot_product / (magnitude_ba * magnitude_bc)
    angle = math.degrees(math.acos(max(-1, min(1, cos_angle))))
    return angle

# 检查右手肘是否高于肩膀
def is_right_elbow_above_shoulder(landmarks):
    return landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y < landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y

# 检查右手肘角度
def check_right_elbow_angle(angle):
    return 160 <= angle <= 170

# 打开视频文件
cap = cv2.VideoCapture("IMG_7239.MOV")  # 请替换为您的视频文件路径

correct_elbow_angle_detected = False
detection_phase = "Not started"  # 用于追踪检测阶段

cv2.namedWindow('Pitcher Pose Analysis', cv2.WINDOW_NORMAL)
# 使用 MediaPipe Pose 进行骨架检测
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        
        # 将图像从 BGR 转换为 RGB
        img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(img_rgb)

        if results.pose_landmarks:
            landmarks = results.pose_landmarks.landmark

            # 计算右手肘角度
            right_elbow_angle = calculate_angle(
                [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y],
                [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y],
                [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            )

            # 检测逻辑
            if detection_phase == "Not started" and is_right_elbow_above_shoulder(landmarks):
                detection_phase = "Started"
                print("检测开始：右手肘高于肩膀")
            
            elif detection_phase == "Started":
                if check_right_elbow_angle(right_elbow_angle):
                    correct_elbow_angle_detected = True
                
                if is_right_elbow_above_shoulder(landmarks) and right_elbow_angle > 170:
                    detection_phase = "Ended"
                    print("检测结束：右手肘高于肩膀且角度大于170度")

            # 绘制骨架
            mp_drawing.draw_landmarks(
                frame, 
                results.pose_landmarks, 
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2)
            )

        # 显示处理后的图像
        cv2.imshow('Pitcher Pose Analysis', frame)

        if cv2.waitKey(5) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# 输出结果
print("\n投球姿势分析结果：")
if correct_elbow_angle_detected:
    print("在检测过程中，右手肘角度有达到正确范围（160-170度）。")
else:
    print("在整个检测过程中，右手肘角度未达到正确范围（160-170度）。")
# Out:
# 检测开始：右手肘高于肩膀
#
# 投球姿势分析结果：
# 在检测过程中，右手肘角度有达到正确范围（160-170度）。

# %%
import sys
import io
sys.stdout = io.TextIOWrapper(sys.stdout.buffer, encoding='utf-8')

import cv2
import mediapipe as mp
import math
import numpy as np

# 初始化 MediaPipe Pose 模型
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# 计算两个向量之间的夹角
def calculate_angle(a, b, c):
    ba = [a[0] - b[0], a[1] - b[1]]  # 向量 BA
    bc = [c[0] - b[0], c[1] - b[1]]  # 向量 BC
    dot_product = ba[0] * bc[0] + ba[1] * bc[1]
    magnitude_ba = math.sqrt(ba[0]**2 + ba[1]**2)
    magnitude_bc = math.sqrt(bc[0]**2 + bc[1]**2)
    cos_angle = dot_product / (magnitude_ba * magnitude_bc)
    angle = math.degrees(math.acos(max(-1, min(1, cos_angle))))
    return angle

# 检查右手肘是否高于肩膀
def is_right_elbow_above_shoulder(landmarks):
    return landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y < landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y

# 检查右手肘角度
def check_right_elbow_angle(angle):
    return 160 <= angle <= 170

# 检查左膝盖角度
def check_left_knee_angle(angle):
    return angle >= 170  # 假设大于170度视为"接近伸直"

# 检查脚尖朝向
def check_foot_direction(landmarks):
    left_foot = np.array([landmarks[mp_pose.PoseLandmark.LEFT_FOOT_INDEX.value].x,
                          landmarks[mp_pose.PoseLandmark.LEFT_FOOT_INDEX.value].y])
    right_foot = np.array([landmarks[mp_pose.PoseLandmark.RIGHT_FOOT_INDEX.value].x,
                           landmarks[mp_pose.PoseLandmark.RIGHT_FOOT_INDEX.value].y])
    foot_direction = left_foot - right_foot
    # 假设y轴正方向为捕手方向，检查脚尖是否大致朝向y轴正方向
    return foot_direction[1] > 0

# 打开视频文件
cap = cv2.VideoCapture("IMG_7239.MOV")  # 请替换为您的视频文件路径

correct_elbow_angle_detected = False
correct_knee_angle_detected = False
correct_foot_direction_detected = False
detection_phase = "Not started"  # 用于追踪检测阶段

cv2.namedWindow('Pitcher Pose Analysis', cv2.WINDOW_NORMAL)
# 使用 MediaPipe Pose 进行骨架检测
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # 将图像从 BGR 转换为 RGB
        img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(img_rgb)

        if results.pose_landmarks:
            landmarks = results.pose_landmarks.landmark

            # 计算右手肘角度
            right_elbow_angle = calculate_angle(
                [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y],
                [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y],
                [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            )

            # 计算左膝盖角度
            left_knee_angle = calculate_angle(
                [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y],
                [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x, landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y],
                [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
            )

            # 检测逻辑
            if detection_phase == "Not started" and is_right_elbow_above_shoulder(landmarks):
                detection_phase = "Started"
                print("检测开始：右手肘高于肩膀")
            
            elif detection_phase == "Started":
                if check_right_elbow_angle(right_elbow_angle):
                    correct_elbow_angle_detected = True
                
                if check_left_knee_angle(left_knee_angle):
                    correct_knee_angle_detected = True
                
                if check_foot_direction(landmarks):
                    correct_foot_direction_detected = True
                
                if is_right_elbow_above_shoulder(landmarks) and right_elbow_angle > 170:
                    detection_phase = "Ended"
                    print("检测结束：右手肘高于肩膀且角度大于170度")

            # 绘制骨架
            mp_drawing.draw_landmarks(
                frame, 
                results.pose_landmarks, 
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2)
            )

        # 显示处理后的图像
        cv2.imshow('Pitcher Pose Analysis', frame)

        if cv2.waitKey(5) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# 输出结果
print("\n投球姿势分析结果：")
if correct_elbow_angle_detected:
    print("- 在检测过程中，右手肘角度有达到正确范围（160-170度）。")
else:
    print("- 在整个检测过程中，右手肘角度未达到正确范围（160-170度）。")

if correct_knee_angle_detected:
    print("- 投球动作结束时，左膝盖接近伸直。")
else:
    print("- 投球动作结束时，左膝盖未充分伸直。")

if correct_foot_direction_detected:
    print("- 脚尖正确朝向捕手方向。")
else:
    print("- 脚尖未正确朝向捕手方向。")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 import sys
#       2 import io
# ----> 3 sys.stdout = io.TextIOWrapper(sys.stdout.buffer, encoding='utf-8')
#       5 import cv2
#       6 import mediapipe as mp
#
# AttributeError: 'OutStream' object has no attribute 'buffer'
